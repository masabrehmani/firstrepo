# %%
import pandas as pd
chilla = pd.read_csv("data_viz.csv")


print(chilla)
# Out:
#              Timestamp  Gender    Age  Location Time_of_class_(pm)  \
# 0    1/3/2022 19:09:29    Male  16-30  Pakistan              10:30
# 1    1/3/2022 19:09:33    Male  16-30  Pakistan              10:00
# 2    1/3/2022 19:09:33    Male  16-30  Pakistan              10:00
# 3    1/3/2022 19:09:33    Male  30-40  Pakistan              09:30
# 4    1/3/2022 19:09:34    Male  16-30      East              09:30
# ..                 ...     ...    ...       ...                ...
# 301  1/3/2022 19:11:51    Male  16-30  Pakistan              09:30
# 302  1/3/2022 19:11:52    Male  16-30  Pakistan              10:30
# 303  1/3/2022 19:11:53    Male  16-30  Pakistan              10:00
# 304  1/3/2022 19:11:54  Female  16-30  Pakistan              10:30
# 305  1/3/2022 19:11:55    Male  16-30  Pakistan              10:30
#
#      Duration_(min)
# 0                60
# 1                60
# 2                30
# 3                30
# 4                60
# ..              ...
# ...

# %%
import pandas as pd
chilla = pd.read_csv("data_viz.csv")

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

p = sns.countplot(x="Gender", hue="Age", data=chilla)
plt.show()

# %%
import pandas as pd
data1 = pd.read_csv("mldata.csv")

import seaborn as sns 
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

sns.countplot(x="likeness", hue="gender", data=data1)
plt.show()

# %%
import pandas as pd 
mldata = pd.read_csv("mldata.csv")

import seaborn as sns
import matplotlib.pyplot as plt
food = sns.set_theme(style="ticks", color_codes=True)

graph = sns.countplot(x="gender", hue="likeness", data=mldata)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

myfile = pd.read_csv("Chilla_data2_for_plots.csv")
myfile.head()
# Out:
#    Gender  Location    Age Blood_group  Glasses Vaccinated Working_expeirence  \
# 0    Male  Pakistan  36-40           B+      No        Yes                  5
# 1    Male  Pakistan  26-30           B+      No        Yes                  1
# 2    Male  Pakistan  31-35           B+     Yes        Yes                5.5
# 3  Female  Pakistan  31-35           O+      No        Yes                  5
# 4  Female  Pakistan  26-30           A-     Yes        Yes                3.5
#
#    Age.1  Weight   Height  hous_of_coding  light_time
# 0  38.00    77.0  179.000             3.0           2
# 1  25.00    53.6  178.000             2.0           6
# 2  31.34    93.0  173.000             2.0           0
# 3  33.00    60.0  157.000             3.0          24
# 4  27.00    59.9  164.544             6.0          12

# %% [markdown]
# # change the value of "y"

# %%
sns.set_theme(color_codes=True , style="ticks")

sns.barplot(x = "Age", y = "light_time", data = myfile,)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='light_time'>

# %%
sns.set_theme(color_codes=True , style="ticks")

sns.barplot(x = "Age", y = "hous_of_coding", data = myfile,)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='hous_of_coding'>

# %%
sns.set_theme(color_codes=True , style="ticks")

sns.barplot(x = "Age", y = "Age.1", data = myfile,)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Age.1'>

# %% [markdown]
# # changes in hue

# %%
sns.set_theme(color_codes=True , style="ticks")

sns.barplot(x = "Age", y = "Age.1", data = myfile,
           hue="Location")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Age.1'>

# %%
sns.set_theme(color_codes=True , style="ticks")

sns.barplot(x = "Age", y = "Age.1", data = myfile,
           hue="Glasses")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Age.1'>

# %%
sns.set_theme(color_codes=True , style="ticks")

sns.barplot(x = "Age", y = "Age.1", data = myfile,
           hue="Vaccinated")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Age.1'>

# %%
sns.set_theme(color_codes=True , style="ticks")

sns.barplot(x = "Age", y = "light_time", data = myfile,
           hue="Gender", saturation=0.5, )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='light_time'>

# %%
sns.set_theme(color_codes=True , style="ticks")

sns.barplot(x = "Age", y = "light_time", data = myfile,
           hue="Gender", saturation=0.5, linewidth=3,
           ci=None)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='light_time'>

# %%
sns.set_theme(color_codes=True , style="ticks")

sns.barplot(x = "Age", y = "light_time", data = myfile,
           hue="Gender", saturation=0.5, linewidth=3,
           ci=None, facecolor=(0.8,0.2,0.5,0.9))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='light_time'>

# %%
sns.set_theme(color_codes=True , style="ticks")

sns.barplot(x = "Age", y = "light_time", data = myfile,
           hue="Gender", saturation=0.5, linewidth=3,
#            ci=None, 
            facecolor=(0.8,0.2,0.5,0.9),
           errcolor=".9")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='light_time'>

# %%
sns.set_theme(color_codes=True , style="ticks")

sns.barplot(x = "Age", y = "light_time", data = myfile,
           hue="Gender", saturation=0.5, linewidth=3,
           ci=None, 
            facecolor=(0.8,0.2,0.5,0.9),
           edgecolor="0", 
           )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='light_time'>

# %%
myfile.head()
# Out:
#    Gender  Location    Age Blood_group  Glasses Vaccinated Working_expeirence  \
# 0    Male  Pakistan  36-40           B+      No        Yes                  5
# 1    Male  Pakistan  26-30           B+      No        Yes                  1
# 2    Male  Pakistan  31-35           B+     Yes        Yes                5.5
# 3  Female  Pakistan  31-35           O+      No        Yes                  5
# 4  Female  Pakistan  26-30           A-     Yes        Yes                3.5
#
#    Age.1  Weight   Height  hous_of_coding  light_time
# 0  38.00    77.0  179.000             3.0           2
# 1  25.00    53.6  178.000             2.0           6
# 2  31.34    93.0  173.000             2.0           0
# 3  33.00    60.0  157.000             3.0          24
# 4  27.00    59.9  164.544             6.0          12

# %%
sns.boxplot(data=myfile, 
           x="Age", y="Weight", hue="Vaccinated")#, ax=None)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Weight'>

# %%
sns.boxplot(data=myfile, 
           x="Age", y="Weight", hue="Vaccinated", ax=None,palette=None, dodge=True)
plt.flag()
plt.title("My own Graph", size=15, weight= "bold")
# Out:
# Text(0.5, 1.0, 'My own Graph')

# %%
myfile.head()
# Out:
#    Gender  Location    Age Blood_group  Glasses Vaccinated Working_expeirence  \
# 0    Male  Pakistan  36-40           B+      No        Yes                  5
# 1    Male  Pakistan  26-30           B+      No        Yes                  1
# 2    Male  Pakistan  31-35           B+     Yes        Yes                5.5
# 3  Female  Pakistan  31-35           O+      No        Yes                  5
# 4  Female  Pakistan  26-30           A-     Yes        Yes                3.5
#
#    Age.1  Weight   Height  hous_of_coding  light_time
# 0  38.00    77.0  179.000             3.0           2
# 1  25.00    53.6  178.000             2.0           6
# 2  31.34    93.0  173.000             2.0           0
# 3  33.00    60.0  157.000             3.0          24
# 4  27.00    59.9  164.544             6.0          12

# %%
sns.lineplot(x="Age", y="Gender", data=myfile)
# plt.figtext(2, 1, "2")
plt.figure(figsize=(5, 1))
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.catplot(x="Age", y="Location", hue="Gender", data=myfile,)
plt.show()

# %%
sns.countplot(data=myfile, x="Location", hue="Gender", y=)
# Out:
# <AxesSubplot:xlabel='Location', ylabel='count'>

# %%
sns.displot(data=myfile, x= "light_time")

# %%
sns.displot(data=myfile, x= "light_time", kde=True)

# %%
sns.displot(data=myfile, x= "light_time", kind="kde")

# %%
sns.displot(data=myfile, x= "light_time", y="Age", hue="Gender")

# %%
sns.histplot(data = myfile,  x = "Height")
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Count'>

# %%
sns.dogplot(data=myfile, x="Age")

# %%
sns.ecdfplot(data=myfile, x ="Age", hue="Gender")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Proportion'>

# %%
myfile.head()
# Out:
#    Gender  Location    Age Blood_group  Glasses Vaccinated Working_expeirence  \
# 0    Male  Pakistan  36-40           B+      No        Yes                  5
# 1    Male  Pakistan  26-30           B+      No        Yes                  1
# 2    Male  Pakistan  31-35           B+     Yes        Yes                5.5
# 3  Female  Pakistan  31-35           O+      No        Yes                  5
# 4  Female  Pakistan  26-30           A-     Yes        Yes                3.5
#
#    Age.1  Weight   Height  hous_of_coding  light_time
# 0  38.00    77.0  179.000             3.0           2
# 1  25.00    53.6  178.000             2.0           6
# 2  31.34    93.0  173.000             2.0           0
# 3  33.00    60.0  157.000             3.0          24
# 4  27.00    59.9  164.544             6.0          12

# %%
sns.swarmplot(data=myfile, x="Age")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 60.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Age'>

# %%
sns.
