# %%
# import libraries
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
import joblib

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = df['species']

# %%
model = DecisionTreeClassifier().fit(X, y)

# %%
model.predict([[5.1,3.5, 1.4, 0.2]])
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['setosa'], dtype=object)

# %%
model = DecisionTreeClassifier().fit(X, y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = DecisionTreeClassifier().fit(X_train, y_train)
predictedValue =  model.predict(X_test)
predictedValue
# Out:
# array(['virginica', 'versicolor', 'setosa', 'virginica', 'setosa',
#        'virginica', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'setosa', 'versicolor', 'versicolor', 'setosa',
#        'setosa', 'virginica', 'versicolor', 'setosa', 'setosa',
#        'virginica', 'setosa', 'setosa', 'versicolor', 'versicolor',
#        'setosa'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
score =  accuracy_score(y_test, predictedValue)

# %%
score
# Out:
# 1.0

# %%
plt.scatter(data = X_test, x = 'petal_width', y = 'petal_length')
plt.plot(X_test, model.predict(X_test))
# Out:
# [<matplotlib.lines.Line2D at 0x1817fd49f90>,
#  <matplotlib.lines.Line2D at 0x1817fd49de0>,
#  <matplotlib.lines.Line2D at 0x1817fd4a0b0>,
#  <matplotlib.lines.Line2D at 0x1817fd4a1d0>]

# %%
plot_tree(model, filled = True)
plt.title('Practice')
# Out:
# Text(0.5, 1.0, 'Practice')

# %%
model = DecisionTreeClassifier().fit(X, y)
joblib.dump(model, "practice.joblib")
# Out:
# ['practice.joblib']

# %%
from sklearn.tree import export_graphviz

# %%
export_graphviz(model, 
out_file = 'practice.dot', 
feature_names=["sepal_length", "sepal_width", 'petal_length', 'petal_width'], 
class_names=sorted(y.unique()), 
label = 'all', 
filled='True')
